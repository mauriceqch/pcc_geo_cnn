# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 5]
import pandas as pd

# %%
d = pd.read_csv('../eval/eval_mpeg_fused.csv')
d2 = pd.read_csv('../eval/eval_64_fused.csv')

# %%
d.head()
# Out:
#    Unnamed: 0   in point count  A->B,h1,p2plane  A->B,h1,p2point  \
# 0           0           281238          11.3474          12.0734
# 1           1           289286          11.6543          12.1488
# 2           2           287076          11.4812          12.1613
# 3           3           280232          11.1665          11.9918
# 4           4           285246          11.4264          12.0357
#
#    A->B,hPSNR1,p2plane  A->B,hPSNR1,p2point  A->B,rms1,p2plane  \
# 0            -4.865420            -5.404070            2.47233
# 1           -10.190300           -10.551200            2.52080
# 2            -8.189420            -8.689300            2.48106
# 3            -6.187130            -6.806500            2.54092
# 4            -0.086091            -0.537295            2.45051
#
#    A->B,rms1,p2point  A->B,rms1PSNR,p2plane  A->B,rms1PSNR,p2point    ...     \
# 0            6.69120                8.37036              -0.277593    ...
# ...

# %%
d2.head()
# Out:
#    Unnamed: 0  A->B,h1,p2plane  A->B,h1,p2point  A->B,hPSNR1,p2plane  \
# 0           0          5.30536          20.0749              1.73820
# 1           1          5.36002          17.4929             -3.44389
# 2           2          6.25895          16.7631             -2.91973
# 3           3          5.49757          19.6469             -0.03221
# 4           4          6.70418          19.3391              4.54518
#
#    A->B,hPSNR1,p2point  A->B,rms1,p2plane  A->B,rms1,p2point  \
# 0             -9.82056           0.096314           0.419176
# 1            -13.71780           0.090172           0.417321
# 2            -11.47680           0.091864           0.396707
# 3            -11.09470           0.088232           0.356267
# 4             -4.65662           0.104588           0.484455
#
#    A->B,rms1PSNR,p2plane  A->B,rms1PSNR,p2point  B->A,h2,p2plane  \
# 0                36.5587                23.7846          7.53922
# ...

# %%
d.columns
# Out:
# Index(['Unnamed: 0', ' in point count', 'A->B,h1,p2plane', 'A->B,h1,p2point',
#        'A->B,hPSNR1,p2plane', 'A->B,hPSNR1,p2point', 'A->B,rms1,p2plane',
#        'A->B,rms1,p2point', 'A->B,rms1PSNR,p2plane', 'A->B,rms1PSNR,p2point',
#        'B->A,h2,p2plane', 'B->A,h2,p2point', 'B->A,hPSNR2,p2plane',
#        'B->A,hPSNR2,p2point', 'B->A,rms2,p2plane', 'B->A,rms2,p2point',
#        'B->A,rms2PSNR,p2plane', 'B->A,rms2PSNR,p2point',
#        'Symmetric,hF,p2plane', 'Symmetric,hF,p2point',
#        'Symmetric,hPSNRF,p2plane', 'Symmetric,hPSNRF,p2point',
#        'Symmetric,rmsF,p2plane', 'Symmetric,rmsF,p2point',
#        'Symmetric,rmsFPSNR,p2plane', 'Symmetric,rmsFPSNR,p2point',
#        'Unnamed: 0.1', 'Unnamed: 20', 'bpov', 'byte_count_centroid_layer',
#        'byte_count_color_layer', 'byte_count_octree_layer',
#        'centroid_byte_size_per_voxel', 'color_byte_size_per_voxel',
#        'compressed_byte_size', 'compressed_byte_size_per_output_point',
# ...

# %%
d2.columns
# Out:
# Index(['Unnamed: 0', 'A->B,h1,p2plane', 'A->B,h1,p2point',
#        'A->B,hPSNR1,p2plane', 'A->B,hPSNR1,p2point', 'A->B,rms1,p2plane',
#        'A->B,rms1,p2point', 'A->B,rms1PSNR,p2plane', 'A->B,rms1PSNR,p2point',
#        'B->A,h2,p2plane', 'B->A,h2,p2point', 'B->A,hPSNR2,p2plane',
#        'B->A,hPSNR2,p2point', 'B->A,rms2,p2plane', 'B->A,rms2,p2point',
#        'B->A,rms2PSNR,p2plane', 'B->A,rms2PSNR,p2point',
#        'Symmetric,hF,p2plane', 'Symmetric,hF,p2point',
#        'Symmetric,hPSNRF,p2plane', 'Symmetric,hPSNRF,p2point',
#        'Symmetric,rmsF,p2plane', 'Symmetric,rmsF,p2point',
#        'Symmetric,rmsFPSNR,p2plane', 'Symmetric,rmsFPSNR,p2point',
#        'Unnamed: 0.1', 'bpov', 'compressed_file', 'compressed_size_in_bits',
#        'csv_file', 'decompressed_file', 'n_points_ori', 'ori_file'],
#       dtype='object')

# %% [markdown]
# # p2plane metrics

# %%
d[['A->B,rms1PSNR,p2plane', 'B->A,rms2PSNR,p2plane', 'Symmetric,rmsFPSNR,p2plane']].describe()
# Out:
#        A->B,rms1PSNR,p2plane  B->A,rms2PSNR,p2plane  \
# count            6010.000000            6008.000000
# mean               18.322937              16.746705
# std                 9.414593              10.765349
# min                -4.486640              -8.127920
# 25%                11.060100               8.122607
# 50%                18.359850              17.114200
# 75%                25.210925              25.031525
# max                49.710200              49.859100
#
#        Symmetric,rmsFPSNR,p2plane
# count                 6010.000000
# mean                    16.678466
# std                     10.713461
# min                     -8.127920
# 25%                      8.124240
# 50%                     16.915350
# 75%                     24.895575
# max                     49.710200

# %%
d[['A->B,rms1PSNR,p2plane', 'B->A,rms2PSNR,p2plane', 'Symmetric,rmsFPSNR,p2plane']].boxplot()

# %%
d2[['A->B,rms1PSNR,p2plane', 'B->A,rms2PSNR,p2plane', 'Symmetric,rmsFPSNR,p2plane']].describe()
# Out:
#        A->B,rms1PSNR,p2plane  B->A,rms2PSNR,p2plane  \
# count            6010.000000            6000.000000
# mean               45.712376              24.074644
# std                 7.670268               7.933598
# min                24.768300               1.741170
# 25%                40.483000              18.905800
# 50%                45.794250              24.279400
# 75%                50.805575              29.240975
# max                72.828300              52.911000
#
#        Symmetric,rmsFPSNR,p2plane
# count                 6010.000000
# mean                    24.116848
# std                      8.009413
# min                      1.741170
# 25%                     18.920075
# 50%                     24.305100
# 75%                     29.260825
# max                     66.894500

# %%
d2[['A->B,rms1PSNR,p2plane', 'B->A,rms2PSNR,p2plane', 'Symmetric,rmsFPSNR,p2plane']].boxplot()

# %% [markdown]
# # p2point metrics

# %%
d[['A->B,rms1PSNR,p2point', 'B->A,rms2PSNR,p2point', 'Symmetric,rmsFPSNR,p2point']].describe()
# Out:
#        A->B,rms1PSNR,p2point  B->A,rms2PSNR,p2point  \
# count            6010.000000            6010.000000
# mean               10.952974              13.775772
# std                10.003853               9.176949
# min               -12.604000              -8.845230
# 25%                 3.224865               6.886735
# 50%                10.983500              14.273700
# 75%                18.419300              20.412200
# max                43.696500              44.028300
#
#        Symmetric,rmsFPSNR,p2point
# count                 6010.000000
# mean                    10.952974
# std                     10.003853
# min                    -12.604000
# 25%                      3.224865
# 50%                     10.983500
# 75%                     18.419300
# max                     43.696500

# %%
d[['A->B,rms1PSNR,p2point', 'B->A,rms2PSNR,p2point', 'Symmetric,rmsFPSNR,p2point']].boxplot()

# %%
d2[['A->B,rms1PSNR,p2point', 'B->A,rms2PSNR,p2point', 'Symmetric,rmsFPSNR,p2point']].describe()
# Out:
#        A->B,rms1PSNR,p2point  B->A,rms2PSNR,p2point  \
# count            6010.000000            6010.000000
# mean               38.997361              21.334558
# std                 9.570571               7.280730
# min                10.674600               0.610350
# 25%                33.797250              16.516000
# 50%                40.294300              21.306350
# 75%                45.412000              25.968875
# max                67.631500              48.929100
#
#        Symmetric,rmsFPSNR,p2point
# count                 6010.000000
# mean                    21.334558
# std                      7.280730
# min                      0.610350
# 25%                     16.516000
# 50%                     21.306350
# 75%                     25.968875
# max                     48.929100

# %%
d2[['A->B,rms1PSNR,p2point', 'B->A,rms2PSNR,p2point', 'Symmetric,rmsFPSNR,p2point']].boxplot()

# %% [markdown]
# # All PSNR metrics

# %%
d[[x for x in d.columns if 'PSNR' in x]].describe()
# Out:
#        A->B,hPSNR1,p2plane  A->B,hPSNR1,p2point  A->B,rms1PSNR,p2plane  \
# count          6010.000000          6010.000000            6010.000000
# mean              6.188109             5.803412              18.322937
# std              10.011570            10.028286               9.414593
# min             -17.600800           -17.891900              -4.486640
# 25%              -1.569033            -1.953500              11.060100
# 50%               6.200970             5.838485              18.359850
# 75%              13.647000            13.272925              25.210925
# max              38.681600            38.418500              49.710200
#
#        A->B,rms1PSNR,p2point  B->A,hPSNR2,p2plane  B->A,hPSNR2,p2point  \
# count            6010.000000          6010.000000          6010.000000
# mean               10.952974             6.368929             6.116065
# std                10.003853             9.933356             9.880430
# ...

# %%
d2[[x for x in d2.columns if 'PSNR' in x]].describe()
# Out:
#        A->B,hPSNR1,p2plane  A->B,hPSNR1,p2point  A->B,rms1PSNR,p2plane  \
# count          6010.000000          6010.000000            6010.000000
# mean              3.919124            -5.343054              45.712376
# std               6.294145             6.617135               7.670268
# min             -18.673000           -34.276500              24.768300
# 25%               0.228656           -10.092350              40.483000
# 50%               3.672250            -4.335775              45.794250
# 75%               7.665037             0.000000              50.805575
# max              29.755300            22.911500              72.828300
#
#        A->B,rms1PSNR,p2point  B->A,hPSNR2,p2plane  B->A,hPSNR2,p2point  \
# count            6010.000000          6010.000000          6010.000000
# mean               38.997361             2.771161             1.427888
# std                 9.570571             6.551491             6.173022
# ...

# %% [markdown]
# ## rmsPSNR

# %%
d[[x for x in d.columns if 'rms' in x and 'PSNR' in x]].boxplot()

# %%
d2[[x for x in d.columns if 'rms' in x and 'PSNR' in x]].boxplot()

# %% [markdown]
# ## hPSNR

# %%
d[[x for x in d.columns if 'hPSNR' in x]].boxplot()

# %%
d2[[x for x in d.columns if 'hPSNR' in x]].boxplot()

# %% [markdown]
# # Bitrates

# %%
d[['bpov']].describe()
# Out:
#               bpov
# count  6010.000000
# mean      0.719472
# std       0.980102
# min       0.025561
# 25%       0.064009
# 50%       0.198611
# 75%       0.898685
# max       3.401794

# %%
d2[['bpov']].describe()
# Out:
#               bpov
# count  6010.000000
# mean      0.691569
# std       0.595146
# min       0.063086
# 25%       0.235245
# 50%       0.388959
# 75%       1.078347
# max       2.123990

# %% [markdown]
# # Points

# %%
d['out point count'].describe()
# Out:
# count      6010.000000
# mean      77879.963727
# std      101771.120639
# min         813.000000
# 25%        5308.500000
# 50%       23173.500000
# 75%       97549.500000
# max      362240.000000
# Name: out point count, dtype: float64

# %%
d[d['decompressed_file'].map(lambda x: 'msft_6/phil9/ply/frame0000' in x)].iloc[0]
# Out:
# Unnamed: 0                                                                            1664
#  in point count                                                                     370798
# A->B,h1,p2plane                                                                    6.61395
# A->B,h1,p2point                                                                    6.83011
# A->B,hPSNR1,p2plane                                                                 14.433
# A->B,hPSNR1,p2point                                                                14.1536
# A->B,rms1,p2plane                                                                  1.58111
# A->B,rms1,p2point                                                                  3.78874
# A->B,rms1PSNR,p2plane                                                              26.8629
# A->B,rms1PSNR,p2point                                                              19.2723
# ...

# %%
d2[d2['compressed_file'].map(lambda x: 'msft_bin_000001/phil9/ply/frame0000' in x)].iloc[0]
# Out:
# Unnamed: 0                                                                  462
# A->B,h1,p2plane                                                          8.3041
# A->B,h1,p2point                                                         34.7131
# A->B,hPSNR1,p2plane                                                     12.4563
# A->B,hPSNR1,p2point                                                   0.0323167
# A->B,rms1,p2plane                                                     0.0830554
# A->B,rms1,p2point                                                      0.285212
# A->B,rms1PSNR,p2plane                                                   52.4548
# A->B,rms1PSNR,p2point                                                   41.7388
# B->A,h2,p2plane                                                         8.94823
# B->A,h2,p2point                                                               9
# B->A,hPSNR2,p2plane                                                     11.8074
# ...
